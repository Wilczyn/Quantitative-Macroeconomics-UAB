# %% [markdown]
# ## Source
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.polyfit.html

# %%
import sympy as sy
import numpy as np
import matplotlib.pyplot as plt
import math
from math import exp

plt.style.use("ggplot")

# Define the variable and the function to approximate
#x = sy.Symbol('x')
#fe = sy.exp(1/x)
#runge = 1/(25*x**2)
#ramp = (x+abs(x))/2

# %%
def plotFE():
    x1 = np.linspace(-1,1,800)
    y1 = np.exp(1/x1)

    
    x_train = np.linspace(-1,1,4)
    y_train = np.exp(1/x_train)
    #Estimate coefficents of polynomial fit
    CoefPolynomial3_FE = np.polyfit(x_train, y_train, 3)
    CoefPolynomial5_FE = np.polyfit(x_train, y_train, 5)
    CoefPolynomial10_FE = np.polyfit(x_train, y_train, 10)
    
    Polynomial3 = np.poly1d(CoefPolynomial3_FE)
    Polynomial5 = np.poly1d(CoefPolynomial5_FE)
    Polynomial10 = np.poly1d(CoefPolynomial10_FE)
    
    plt.scatter(x_train,y_train, c= 'black', label='Interpolated points - evenly-spaced nodes')
    plt.plot(x1,Polynomial3(x1),label='Cubic polynomial')
    plt.plot(x1,Polynomial5(x1),label='Polynomial of order 5')
    plt.plot(x1,Polynomial10(x1),label='Polynomial of order 10')
    plt.plot(x1,y1,label='exp(1/x)')
    plt.xlim([-1,1])
    plt.ylim([-10,40])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.title('exp(1/x), Evenly-spaced nodes, monomials')
    plt.rcParams["figure.figsize"] = (12,8)
    # Plot the function
    
    plt.show()

plotFE()
# Out:
# C:\Users\adamw\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in exp
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\adamw\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RankWarning: Polyfit may be poorly conditioned
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\adamw\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RankWarning: Polyfit may be poorly conditioned
#   # This is added back by InteractiveShellApp.init_path()

# %%
def plotFE2():
    x1 = np.linspace(-1,1,800)
    y1 = np.exp(1/x1)
    # Plot the function
    #plt.plot(x1,y1,label='exp(1/x)')
    
    x_train = np.linspace(-1,1,4)
    y_train = np.exp(1/x_train)
    #Estimate coefficents of polynomial fit
    CoefPolynomial3_FE = np.polyfit(x_train, y_train, 3)
    CoefPolynomial5_FE = np.polyfit(x_train, y_train, 5)
    CoefPolynomial10_FE = np.polyfit(x_train, y_train, 10)
    
    Polynomial3 = np.poly1d(CoefPolynomial3_FE)
    Polynomial5 = np.poly1d(CoefPolynomial5_FE)
    Polynomial10 = np.poly1d(CoefPolynomial10_FE)
    
    #plt.plot(x_train,y_train,label='Interpolated points', marker='o')
    plt.plot(x1,abs(y1 - Polynomial3(x1)),label='Cubic polynomial')
    plt.plot(x1,abs(y1 - Polynomial5(x1)),label='Polynomial of order 5')
    plt.plot(x1,abs(y1 - Polynomial10(x1)),label='Polynomial of order 10')
    
    plt.xlim([-1,1])
    plt.ylim([0,25])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.title('Error of the approximation, evenly-spaced nodes, monomials')
    plt.rcParams["figure.figsize"] = (12,6)
    plt.show()

plotFE2()
# Out:
# C:\Users\adamw\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: overflow encountered in exp
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\adamw\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RankWarning: Polyfit may be poorly conditioned
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\adamw\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RankWarning: Polyfit may be poorly conditioned
#   if sys.path[0] == '':

# %%
def plotRUNGE():
    x1 = np.linspace(-1,1,1000)
    y1 = 1/(1+25*x1**2)
    
    #train
    x_train = np.linspace(-1,1,15)
    y_train = 1/(1+25*x_train**2)
    

    
    #Estimate coefficents of polynomial fit
    CoefPolynomial3 = np.polyfit(x_train, y_train, 3)
    CoefPolynomial5 = np.polyfit(x_train, y_train, 5)
    CoefPolynomial10 = np.polyfit(x_train, y_train, 10)
    
    Polynomial3 = np.poly1d(CoefPolynomial3)
    Polynomial5 = np.poly1d(CoefPolynomial5)
    Polynomial10 = np.poly1d(CoefPolynomial10)
    
    plt.scatter(x_train,y_train, c= 'black', label='Interpolated points - evenly-spaced nodes')
    #plt.plot(x_train,y_train,label='Interpolated points', marker = 'o')
    plt.plot(x1,Polynomial3(x1),label='Cubic polynomial')
    plt.plot(x1,Polynomial5(x1),label='Polynomial of order 5')
    plt.plot(x1,Polynomial10(x1),label='Polynomial of order 10')
    
        # Plot the function
    plt.plot(x1,y1,label='Runge function 1/(1+25x^2)')
    
    plt.xlim([-1,1])
    plt.ylim([-0.1,1])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.title('RUNGE function, evenly-spaced nodes, monomials')
    plt.rcParams["figure.figsize"] = (12,8)
    plt.show()

plotRUNGE()

# %%
def plotRUNGE2():
    x1 = np.linspace(-1,1,1000)
    y1 = 1/(1+25*x1**2)
    
    #train
    x_train = np.linspace(-1,1,1000)
    y_train = 1/(1+25*x_train**2)
    
    # Plot the function
    #plt.plot(x1,y1,label='Runge function 1/(1+25x^2)')
    
    #Estimate coefficents of polynomial fit
    CoefPolynomial3 = np.polyfit(x_train, y_train, 3)
    CoefPolynomial5 = np.polyfit(x_train, y_train, 5)
    CoefPolynomial10 = np.polyfit(x_train, y_train, 10)
    
    Polynomial3 = np.poly1d(CoefPolynomial3)
    Polynomial5 = np.poly1d(CoefPolynomial5)
    Polynomial10 = np.poly1d(CoefPolynomial10)
    
    plt.plot(x1,abs(y1 - Polynomial3(x1)),label='Cubic polynomial')
    plt.plot(x1,abs(y1 - Polynomial5(x1)),label='Polynomial of order 5')
    plt.plot(x1,abs(y1 - Polynomial10(x1)),label='Polynomial of order 10')
    
    plt.xlim([-1,1])
    plt.ylim([0,0.5])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.title('Error function, RUNGE, evenly-spaced nodes, monomials')
    plt.rcParams["figure.figsize"] = (12,6)
    plt.show()

plotRUNGE2()

# %%
def plotRAMP():
    x1 = np.linspace(-1,1,800)
    y1 = (x1+abs(x1))/2

    
    #train
    x_train = np.linspace(-1,1,5)
    y_train = (x_train+abs(x_train))/2
    
    #Estimate coefficents of polynomial fit
    CoefPolynomial3 = np.polyfit(x_train, y_train, 3)
    CoefPolynomial5 = np.polyfit(x_train, y_train, 5)
    CoefPolynomial10 = np.polyfit(x_train, y_train, 10)
    
    Polynomial3 = np.poly1d(CoefPolynomial3)
    Polynomial5 = np.poly1d(CoefPolynomial5)
    Polynomial10 = np.poly1d(CoefPolynomial10)
    
    plt.scatter(x_train,y_train, c= 'black', label='Interpolated points - evenly-spaced nodes')
    plt.plot(x1,Polynomial3(x1),label='Cubic polynomial')
    plt.plot(x1,Polynomial5(x1),label='Polynomial of order 5')
    plt.plot(x1,Polynomial10(x1),label='Polynomial of order 10')
    
        # Plot the function
    plt.plot(x1,(x1+abs(x1))/2,label='(x+abs(x))/2')
    
    plt.xlim([-1,1])
    plt.ylim([-0.25,1.25])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.title('RAMP funciton, evenly-spaced nodes, monomials')
    plt.rcParams["figure.figsize"] = (12,8)
    plt.show()

plotRAMP()
# Out:
# C:\Users\adamw\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: RankWarning: Polyfit may be poorly conditioned
#   if sys.path[0] == '':
# C:\Users\adamw\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: RankWarning: Polyfit may be poorly conditioned
#   del sys.path[0]

# %%
def plotRAMP():
    x1 = np.linspace(-1,1,800)
    y1 = (x1+abs(x1))/2
    # Plot the function
    #plt.plot(x1,(x1+abs(x1))/2,label='(x+abs(x))/2')
    
    #train
    x_train = np.linspace(-1,1,5)
    y_train = (x_train+abs(x_train))/2
    
    #Estimate coefficents of polynomial fit
    CoefPolynomial3 = np.polyfit(x_train, y_train, 3)
    CoefPolynomial5 = np.polyfit(x_train, y_train, 5)
    CoefPolynomial10 = np.polyfit(x_train, y_train, 10)
    
    Polynomial3 = np.poly1d(CoefPolynomial3)
    Polynomial5 = np.poly1d(CoefPolynomial5)
    Polynomial10 = np.poly1d(CoefPolynomial10)
    
    #plt.scatter(x_train,y_train, c= 'black', label='Interpolated points - evenly-spaced nodes')
    plt.plot(x1,abs(y1 - Polynomial3(x1)),label='Cubic polynomial')
    plt.plot(x1,abs(y1 - Polynomial5(x1)),label='Polynomial of order 5')
    plt.plot(x1,abs(y1 - Polynomial10(x1)),label='Polynomial of order 10')
    
    plt.xlim([-1,1])
    plt.ylim([0,0.2])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True)
    plt.title('Error function, ramp, evenly-spaced nodes, monomials')
    plt.rcParams["figure.figsize"] = (12,6)
    plt.show()

plotRAMP()
# Out:
# C:\Users\adamw\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: RankWarning: Polyfit may be poorly conditioned
#   del sys.path[0]
# C:\Users\adamw\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: RankWarning: Polyfit may be poorly conditioned
